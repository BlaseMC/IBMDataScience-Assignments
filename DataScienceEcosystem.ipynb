# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Blase Cornett

# %% [markdown]
# In this method, Data Science Tools and Ecosystems are summarized

# %% [markdown]
# **Objectives**
# - Usage of JupyterNotebooks
# - Introduction GitHub
# - Introduction to R Software Visualizations

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Scikit-Learn
# 4. PyTorch

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |PostgreSQL|
# |Apache Spark|
# |GitHub|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to multiple then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
(200 / 60)
# Out:
# 3.3333333333333335
